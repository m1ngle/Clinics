# %%
pip install haversine
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import haversine

# %%
pip install folium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import haversine as hs
import folium

# %%
from haversine import Unit

# %%
from geopy.extra.rate_limiter import RateLimiter

# %%
from googlemaps import Client as GoogleMaps

# %%
gmaps = GoogleMaps('AIzaSyCyNpr6pwBeHRECEn1FpwDhoxRAs_6w9Q0')

# %%
addresses = pd.read_csv("C:\\Users\\matth\\OneDrive\\Documents\\Data Science\\Abortion Map\\address.csv")
addresses.head()
# Out:
#                                         Full_Address
# 0  1511 Starling Drive, Henrico, Richmond, VA, 23229
# 1             3220 Latrobe Dr., Charlotte, NC, 28211
# 2        1604 Jones Franklin Rd., Raleigh, NC, 27606
# 3        2903 Professional Pkwy., Augusta, GA, 30907
# 4         519 Forest Parkway, Forest Park, GA, 30297

# %%
addresses2 = pd.read_csv("C:\\Users\\matth\\OneDrive\\Documents\\Data Science\\Abortion Map\\address2.csv")
addresses2.head()
# Out:
#                                    Full_Address
# 0         1212 7th St. NW, Rochester, MN, 55901
# 1   114 University Avenue, Rochester, NY, 14605
# 2  1000 E. Army Post Rd., Des Moines, IA, 50315
# 3            11 Burnham Ave., Rutland, VT, 5701
# 4   3131 La Canada Street, Las Vegas, NV, 89169

# %%
addresses.head()
# Out:
#                                         Full_Address lat long
# 0  1511 Starling Drive, Henrico, Richmond, VA, 23229
# 1             3220 Latrobe Dr., Charlotte, NC, 28211
# 2        1604 Jones Franklin Rd., Raleigh, NC, 27606
# 3        2903 Professional Pkwy., Augusta, GA, 30907
# 4         519 Forest Parkway, Forest Park, GA, 30297

# %%
addresses2['lat'] = ""
addresses2['long'] = ""

# %%
geocode_result = gmaps.geocode('94112')

print("geocode result",geocode_result[0]["geometry"]["location"])
# Out:
# geocode result {'lat': 37.72254909999999, 'lng': -122.4410618}

# %%
print(len(addresses2))
# Out:
# 83

# %%
for x in range(len(addresses)):
    try:
        time.sleep(1) #to add delay in case of large DFs
        geocode_result = gmaps.geocode(addresses['Full_Address'][x])
        #addresses2['lat'][x] = geocode_result[x]['geometry']['location'] ['lat']
        #addresses2['long'][x] = geocode_result[x]['geometry']['location']['lng']
    except IndexError:
        print("Address was wrong...")
    except Exception as e:
        print("Unexpected error occurred.", e )
addresses2.head()
# Out:
#                                    Full_Address lat long
# 0         1212 7th St. NW, Rochester, MN, 55901
# 1   114 University Avenue, Rochester, NY, 14605
# 2  1000 E. Army Post Rd., Des Moines, IA, 50315
# 3            11 Burnham Ave., Rutland, VT, 5701
# 4   3131 La Canada Street, Las Vegas, NV, 89169

# %%
addresses2.head()
# Out:
#                                    Full_Address      lat     long
# 0         1212 7th St. NW, Rochester, MN, 55901  37.6053 -77.5683
# 1   114 University Avenue, Rochester, NY, 14605   35.199 -80.8036
# 2  1000 E. Army Post Rd., Des Moines, IA, 50315  35.7595 -78.7292
# 3            11 Burnham Ave., Rutland, VT, 5701  33.4997 -82.0806
# 4   3131 La Canada Street, Las Vegas, NV, 89169  33.6211 -84.3726

# %%
addresses2.to_csv(r"C:\\Users\\matth\\OneDrive\\Documents\\Data Science\\Abortion Map\\coordaddress2.csv", index = True)

# %%
loc=pd.read_csv('C:\\Users\\matth\\OneDrive\\Documents\\Data Science\\Abortion Map\\coordaddress.csv')

# %%
loc.head()
# Out:
#                                              address        lat        long  \
# 0     4831 Sparkman Drive NW, Huntstville, AL, 35810  34.757704  -86.636578
# 1      811 South Perry Street, Montgomery, AL, 36104  32.366142  -86.306712
# 2  535 Jack Warner Parkway NW, Tuscaloosa, AL, 35404  42.339606  -71.104982
# 3        4 Office Park Drive, Little Rock, AR, 72211  34.746143  -92.397475
# 4             1615 E Osborn Road, Phoenix, AZ, 85016  33.487048 -112.046845
#
#    St Clinic                                      coor      AL1      AL2  \
# 0  AL    AL1         (34.757704100000005, -86.6365781)     0.00   166.33
# 1  AL    AL2  (32.366141600000006, -86.30671190000001)   166.33     0.00
# 2  AL    AL3          (42.3396063, -71.10498199999999)   986.98  1079.63
# 3  AR    AR1         (34.746142799999994, -92.3974746)   327.00   387.24
# 4  AZ    AZ1                (33.4870478, -112.0468452)  1452.22  1490.99
#
# ...

# %%
# concatenating lat and long to create a consolidated location as accepted by havesine function
loc['coor'] = list(zip(loc.lat, loc.long))

# %%
# defining a  function to calculate distance between two locations 
# loc1= location of an existing hotel
# loc2= location of customers

def distance_from(loc1,loc2): 
    dist=hs.haversine(loc1,loc2,unit=Unit.MILES)
    return round(dist,2)

# %%
# running a loop which will parse customers location one by one to distance from function 
for _,row in loc.iterrows():
    loc[row.Clinic]=loc['coor'].apply(lambda x: distance_from(row.coor,x))

# %%
loc.replace(0,np.nan, inplace=True)

# %%
loc.head()
# Out:
#                                              address        lat        long  \
# 0     4831 Sparkman Drive NW, Huntstville, AL, 35810  34.757704  -86.636578
# 1      811 South Perry Street, Montgomery, AL, 36104  32.366142  -86.306712
# 2  535 Jack Warner Parkway NW, Tuscaloosa, AL, 35404  42.339606  -71.104982
# 3        4 Office Park Drive, Little Rock, AR, 72211  34.746143  -92.397475
# 4             1615 E Osborn Road, Phoenix, AZ, 85016  33.487048 -112.046845
#
#    St Clinic                                      coor      AL1      AL2  \
# 0  AL    AL1         (34.757704100000005, -86.6365781)      NaN   166.33
# 1  AL    AL2  (32.366141600000006, -86.30671190000001)   166.33      NaN
# 2  AL    AL3          (42.3396063, -71.10498199999999)   986.98  1079.63
# 3  AR    AR1         (34.746142799999994, -92.3974746)   327.00   387.24
# 4  AZ    AZ1                (33.4870478, -112.0468452)  1452.22  1490.99
#
# ...

# %%
loc.to_csv(r"C:\\Users\\matth\\OneDrive\\Documents\\Data Science\\Abortion Map\\clinic_dist.csv", index = True)

# %%
def create_map(loc,clinic_list):
    m = folium.Map(location=[loc.lat.mean(), loc.long.mean()], zoom_start=4, 
                  tiles='CartoDB positron')
    
   
    
    for _, row in loc.iterrows():
         
        if row['Condition']=='Out':
            cluster_colour='red'
        else:
            cluster_colour = 'green'
        
        folium.CircleMarker(
            location= [row['latitudes'],row['longitudes']],
            radius=5,
            popup= row[['Condition','address']],
            color=cluster_colour,
            fill=True,
            fill_color=cluster_colour
            ).add_to(m)
    
    for _, row in loc.iterrows(): 
        folium.Marker(
            location= [row['latitudes'],row['longitudes']],
            radius=5,
            popup= row['Clinic'],
            color='red',
            fill=True,
            fill_color='red'
             ).add_to(m)
    #for _, row in loc.iterrows(): 
    #    folium.Circle(
    #        location= [row['lat'],row['long']],
    #        radius=160934,
    #        popup= row['Clinic'],
    #        color='black',
    #        fill=False,
    #    ).add_to(m)
        
    return m

# %%
loc['Condition']='Out'

for i in clinic_list:
    loc['Condition'][loc.Condition=='Out']=loc[loc.Condition=='Out'][i].apply(lambda x: 'In' if x<160.934 else 'Out')
# Out:
# <ipython-input-274-b39af047a9a6>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loc['Condition'][loc.Condition=='Out']=loc[loc.Condition=='Out'][i].apply(lambda x: 'In' if x<160.934 else 'Out')

# %%
m= create_map(loc,clinic_list)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
import plotly.graph_objects as go

# %%
df = pd.read_csv('C:\\Users\\matth\\OneDrive\\Documents\\Data Science\\Abortion Map\\clinic_dist5.csv',encoding = 'latin1')

# %%
df.head()
# Out:
#                                              address  \
# 0     4831 Sparkman Drive NW, Huntstville, AL, 35810
# 1      811 South Perry Street, Montgomery, AL, 36104
# 2  535 Jack Warner Parkway NW, Tuscaloosa, AL, 35404
# 3        4 Office Park Drive, Little Rock, AR, 72211
# 4             1615 E Osborn Road, Phoenix, AZ, 85016
#
#                                                 name clinic  latitudes  \
# 0  Alabama Women's Center for Reproductive Altern...    AL1  34.758382
# 1         Reproductive Health Services of Montgomery    AL2  32.366239
# 2                        West Alabama Women's Center    AL3  33.219260
# 3               Little Rock Family Planning Services    AR1  34.746210
# 4                              Acacia Women's Center    AZ1  33.487375
#
#    longitudes  max_min_dist  population   clinic_dist      pop
# 0  -86.636142           100   1,971,112         97.19  1971112
# 1  -86.306915           152   1,619,754         79.11  1619754
# ...

# %%
df.columns = [c.strip() for c in df.columns]
for col in df.columns:
    df[col] = df[col].astype(str)

# %%
fig = go.Figure(data=go.Scattergeo(
    lat = df['latitudes'],
    lon = df['longitudes'],
    text = df['name']+
    '<br>'+df['address']+'<br>'+'<b>'+'Maximum Distance to Access Clinic '+'</b>'
    +df['max_min_dist'] + ' miles'+'<br>'+'<b>'+'Population Served '+'</b>'
    +df['population'],
    marker = dict(
        color = df['clinic_dist'].astype(float),
        colorscale = 'Portland',
        reversescale = False,
        opacity = 0.7,
        size = df['clinic_dist'].astype(float)/4,
        colorbar = dict(
            title = '<b>'+"Miles to Nearest Clinic",
            titleside = "top",
            outlinecolor = "rgba(68, 68, 68, 0)",
            ticks = "outside",
            title_font_size=16,
            title_font_family="Rockwell",
            showticksuffix = "last",
            dtick = 25
        )
    )
))

fig.update_layout(
    geo = dict(
        scope = 'north america',
        showland = True,
        landcolor = "rgb(212, 212, 212)",
        subunitcolor = "rgb(255, 255, 255)",
        countrycolor = "rgb(255, 255, 255)",
        showlakes = True,
        lakecolor = "rgb(255, 255, 255)",
        showsubunits = True,
        showcountries = True,
        resolution = 50,        
        projection = dict(
            type = 'conic conformal',
            rotation_lon = -100
        ),
        lonaxis = dict(
            showgrid = False,
            gridwidth = 0.5,
            range= [ -123.0, -67.0 ],
            dtick = 5
        ),
        lataxis = dict (
            showgrid = False,
            gridwidth = 0.5,
            range= [ 26.0, 50.0 ],
            dtick = 5
        )
    ),
    hoverlabel=dict(
        bgcolor="white",
        font_size=16,
        font_family="Rockwell"
    ),
    
    title='Abortion Clinics' +'<br>'+'(Scroll to Zoom)',
)



fig.show()
# Out:
# <div>                            <div id="61b78c03-c67c-439d-9c5f-ddcceb831c92" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("61b78c03-c67c-439d-9c5f-ddcceb831c92")) {                    Plotly.newPlot(                        "61b78c03-c67c-439d-9c5f-ddcceb831c92",                        [{"lat": ["34.758382", "32.366238800000005", "33.2192598", "34.7462098", "33.4873751", "33.496790999999995", "33.538617200000004", "33.4634541", "34.091553000000005", "34.084888899999996", "33.8058542", "35.382071999999994", "34.1901495", "33.937049", "34.02151", "32.809478999999996", "36.7468505", "34.1583849", "33.960592", "34.680820000000004", "33.7975706", "34.061683", "34.255573", "37.6722648", "37.81797529999999", "34.216741", "34.0792871", "33.905473", "38.
# ...

# %%
import plotly.graph_objects as go
import chart_studio
import chart_studio.plotly as py
from chart_studio.tools import set_config_file
set_config_file(
    plotly_domain="https://plotly.com", 
    plotly_api_domain="https://api.plotly.com"
)
username = 'mingle' # your username
api_key = 'ZBe7bAaNWgpRZyI0qC8x' # your api key - go to profile > settings > regenerate key
chart_studio.tools.set_credentials_file(username=username, api_key=api_key)

# %%
py.plot(fig, filename = 'Abortion Clinic Distance', auto_open=True)
# Out:
# 'https://plotly.com/~mingle/53/'

# %%
df1.head()
# Out:
#                                              address  \
# 0     4831 Sparkman Drive NW, Huntstville, AL, 35810
# 1      811 South Perry Street, Montgomery, AL, 36104
# 2  535 Jack Warner Parkway NW, Tuscaloosa, AL, 35404
# 3        4 Office Park Drive, Little Rock, AR, 72211
# 4             1615 E Osborn Road, Phoenix, AZ, 85016
#
#                                                 name clinic  latitudes  \
# 0  Alabama Women's Center for Reproductive Altern...    AL1  34.758382
# 1         Reproductive Health Services of Montgomery    AL2  32.366239
# 2                        West Alabama Women's Center    AL3  33.219260
# 3               Little Rock Family Planning Services    AR1  34.746210
# 4                              Acacia Women's Center    AZ1  33.487375
#
#    longitudes                                      coor    36201    35565  \
# 0  -86.636142                   (34.758382, -86.636142)    88.21    66.66
# ...

# %%
df1.to_csv(r"C:\\Users\\matth\\OneDrive\\Documents\\Data Science\\Abortion Map\\zip_dist_fix.csv", index = False)

# %%
df1_transposed = df1.T

# %%
df1_transposed.head(10)
# Out:
#                                                           0    \
# address        4831 Sparkman Drive NW, Huntstville, AL, 35810
# name        Alabama Women's Center for Reproductive Altern...
# clinic                                                    AL1
# latitudes                                             34.7584
# longitudes                                           -86.6361
# coor                                  (34.758382, -86.636142)
# 36201                                                   88.21
# 35565                                                   66.66
# 35294                                                   85.52
# 36689                                                  297.08
#
#                                                       1    \
# address     811 South Perry Street, Montgomery, AL, 36104
# name           Reproductive Health Services of Montgomery
# clinic                                                AL2
# ...

# %%
df1_transposed.to_csv(r"C:\\Users\\matth\\OneDrive\\Documents\\Data Science\\Abortion Map\\zip_dist_fix.csv")

# %%
loc2.head()
# Out:
#                                              address  \
# 0     4831 Sparkman Drive NW, Huntstville, AL, 35810
# 1      811 South Perry Street, Montgomery, AL, 36104
# 2  535 Jack Warner Parkway NW, Tuscaloosa, AL, 35404
# 3        4 Office Park Drive, Little Rock, AR, 72211
# 4             1615 E Osborn Road, Phoenix, AZ, 85016
#
#                                                 name clinic  latitudes  \
# 0  Alabama Women's Center for Reproductive Altern...    AL1  34.758382
# 1         Reproductive Health Services of Montgomery    AL2  32.366239
# 2                        West Alabama Women's Center    AL3  33.219260
# 3               Little Rock Family Planning Services    AR1  34.746210
# 4                              Acacia Women's Center    AZ1  33.487375
#
#    longitudes  max_min_dist  population   clinic_dist      pop Condition
# 0  -86.636142           100    1,971,112        97.19  1971112       Out
# ...

# %%
clinic_list = ['AL1',	'AL2',	'AL3',	'AR1',	'AZ1',	'AZ2',	'AZ3',	'AZ4',	'CA1',	'CA2',	'CA3',	'CA4',	'CA5',	'CA6',	'CA7',	'CA8',	'CA9',	'CA10',	'CA11',	'CA12',	'CA13',	'CA14',	'CA15',	'CA16',	'CA17',	'CA18',	'CA19',	'CA20',	'CA21',	'CA22',	'CA23',	'CA24',	'CA25',	'CA26',	'CA27',	'CA28',	'CA29',	'CA30',	'CA31',	'CA32',	'CA33',	'CA34',	'CA35',	'CA36',	'CA37',	'CA38',	'CA39',	'CO1',	'CO2',	'CO3',	'CO4',	'CO5',	'CO6',	'CO7',	'CO8',	'CO9',	'CO10',	'CO11',	'CO12',	'CO13',	'CO14',	'CO15',	'CT1',	'CT2',	'DC1',	'DC2',	'DC3',	'DC4',	'DE1',	'DE2',	'DE3',	'FL1',	'FL2',	'FL3',	'FL4',	'FL5',	'FL6',	'FL7',	'FL8',	'FL9',	'FL10',	'FL11',	'FL12',	'FL13',	'FL14',	'FL15',	'FL16',	'FL17',	'FL18',	'FL19',	'FL20',	'FL21',	'FL22',	'FL23',	'FL24',	'FL25',	'FL26',	'FL27',	'FL28',	'FL29',	'FL30',	'FL31',	'FL32',	'FL33',	'FL34',	'FL35',	'GA1',	'GA2',	'GA3',	'GA4',	'GA5',	'GA6',	'GA7',	'GA8',	'GA9',	'GA3',	'IA1',	'IA2',	'IA3',	'IA4',	'IA5',	'IA6',	'IL1',	'IL2',	'IL3',	'IL4',	'IL5',	'IL6',	'IL7',	'IL8',	'IL9',	'IL10',	'IL11',	'IN1',	'IN2',	'IN3',	'KS1',	'Ks2',	'KY1',	'LA1',	'LA2',	'LA3',	'MA1',	'MA2',	'MA3',	'MA4',	'MA5',	'MA6',	'MA7',	'MA8',	'MA9',	'MA10',	'MA11',	'MA12',	'MA13',	'MD1',	'MD2',	'MD3',	'MD4',	'MD5',	'MD6',	'MD7',	'MD8',	'MD9',	'MD10',	'MD11',	'MD11',	'MD13',	'MD14',	'MD15',	'MD16',	'MD17',	'ME1',	'ME2',	'ME3',	'ME4',	'ME5',	'ME6',	'ME7',	'ME8',	'ME9',	'ME10',	'ME11',	'ME12',	'ME13',	'ME14',	'ME15',	'ME16',	'ME17',	'ME18',	'ME19',	'ME20',	'ME21',	'ME22',	'MI1',	'MI2',	'MI3',	'MI4',	'MI5',	'MI6',	'MI7',	'MI8',	'MI9',	'MN1',	'MN2',	'MN3',	'MN4',	'MN5',	'MN6',	'MN7',	'MO1',	'MS1',	'MT1',	'MT2',	'MT3',	'MT4',	'MT5',	'NC1',	'NC2',	'NC3',	'NC4',	'NC5',	'NC6',	'NC7',	'NC8',	'NC9',	'NC10',	'NC11',	'NC12',	'NC13',	'NC14',	'NC15',	'ND1',	'NE1',	'NE2',	'NH1',	'NH2',	'NH3',	'NH4',	'NJ1',	'NJ2',	'NJ3',	'NJ4',	'NJ5',	'NJ6',	'NJ7',	'NJ8',	'NJ9',	'NJ10',	'NJ11',	'NJ12',	'NJ13',	'NJ14',	'NJ15',	'NJ16',	'NJ17',	'NM1',	'NM2',	'NM3',	'NM4',	'NV1',	'NV2',	'NV3',	'NV4',	'NV5',	'NV6',	'NV7',	'NY1',	'NY2',	'NY3',	'NY4',	'NY5',	'NY6',	'NY7',	'NY8',	'NY9',	'NY10',	'NY11',	'NY12',	'NY13',	'NY14',	'NY15',	'NY16',	'NY17',	'NY18',	'NY19',	'NY20',	'NY21',	'NY22',	'NY23',	'OH1',	'OH2',	'OH3',	'OH4',	'OH5',	'OH6',	'OH7',	'OH8',	'OK1',	'OK2',	'OR1',	'OR2',	'OR3',	'OR4',	'OR5',	'OR6',	'OR7',	'PA1',	'PA2',	'PA3',	'PA4',	'PA5',	'PA6',	'PA7',	'RI1',	'SC1',	'SC2',	'SD1',	'TN1',	'TN2',	'TN3',	'TN4',	'TN5',	'TN6',	'TX1',	'TX2',	'TX3',	'TX4',	'TX5',	'TX6',	'TX7',	'TX8',	'TX9',	'TX10',	'TX11',	'TX12',	'TX13',	'TX14',	'TX15',	'TX16',	'UT1',	'UT2',	'VA1',	'VA2',	'VA3',	'VA4',	'VA5',	'VA6',	'VA7',	'VT1',	'VT2',	'VT3',	'VT4',	'VT5',	'VT6',	'WA1',	'WA2',	'WA3',	'WA4',	'WA5',	'WA6',	'WA7',	'WA8',	'WA9',	'WI1',	'WV1'
]

# %%
def create_map(loc2,clinic_list):
    m = folium.Map(location=[loc2.latitudes.mean(), loc2.longitudes.mean()], zoom_start=4, 
                  tiles='CartoDB positron')
    
   
    
    for _, row in loc2.iterrows():
         
        if row['Condition']=='Out':
            cluster_colour='red'
        else:
            cluster_colour = 'green'
        
        folium.CircleMarker(
            location= [row['latitudes'],row['longitudes']],
            radius=5,
            popup= row[['Condition','address']],
            color=cluster_colour,
            fill=True,
            fill_color=cluster_colour
            ).add_to(m)
    
    for _, row in loc2.iterrows(): 
        folium.Marker(
            location= [row['latitudes'],row['longitudes']],
            radius=5,
            popup= [row['name'],row['dist_pre'],row['max_min_dist']],
            color='red',
            fill=True,
            fill_color='red'
             ).add_to(m)
    #for _, row in loc2.iterrows(): 
    #    folium.Circle(
    #        location= [row['latitudes'],row['longitudes']],
    #        radius=160934,
    #        popup= row['clinic'],
    #        color='black',
    #        fill=False,
    #    ).add_to(m)
        
    return m

# %%
m= create_map(loc2,clinic_list)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...
